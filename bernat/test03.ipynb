# %% [markdown]
# # Test 03

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import math
from skimage import draw
from scipy import signal
from PIL import Image

# %%
#Import image
dist_00000 = Image.open('from_camera/test03/dist_00000.png')
realsize=dist_00000.size
factor=4
newsize=tuple(int(ti/factor) for ti in realsize)

def image_open_mean_show(name,new_size,colormap):
    location='from_camera/test03/dist_'+name+'.png'
    image_im = Image.open(location)
    image_im=image_im.resize(new_size,Image.ANTIALIAS)
    image_im = np.array(image_im,dtype=float)
    image_im = image_im[:, :, 0]
    image_im = image_im - image_im.mean()
    plt.imshow(image_im,cmap=colormap)
    plt.title(str(name))
    # plt.show()
    return image_im

dist_00000=image_open_mean_show('00000',newsize,'gray')
dist_00025=image_open_mean_show('00025',newsize,'gray')
dist_00050=image_open_mean_show('00050',newsize,'gray')
dist_00075=image_open_mean_show('00075',newsize,'gray')
dist_00100=image_open_mean_show('00100',newsize,'gray')
dist_00125=image_open_mean_show('00125',newsize,'gray')
dist_00150=image_open_mean_show('00150',newsize,'gray')
dist_00175=image_open_mean_show('00175',newsize,'gray')
dist_00200=image_open_mean_show('00200',newsize,'gray')
dist_00225=image_open_mean_show('00225',newsize,'gray')
dist_00250=image_open_mean_show('00250',newsize,'gray')
dist_00275=image_open_mean_show('00275',newsize,'gray')
dist_00300=image_open_mean_show('00300',newsize,'gray')
dist_00325=image_open_mean_show('00325',newsize,'gray')
dist_00350=image_open_mean_show('00350',newsize,'gray')
dist_00375=image_open_mean_show('00375',newsize,'gray')
dist_00400=image_open_mean_show('00400',newsize,'gray')
dist_00425=image_open_mean_show('00425',newsize,'gray')
dist_00450=image_open_mean_show('00450',newsize,'gray')
dist_00475=image_open_mean_show('00475',newsize,'gray')
dist_00500=image_open_mean_show('00500',newsize,'gray')
dist_00525=image_open_mean_show('00525',newsize,'gray')
dist_00550=image_open_mean_show('00550',newsize,'gray')
dist_00575=image_open_mean_show('00575',newsize,'gray')
dist_00600=image_open_mean_show('00600',newsize,'gray')
dist_00625=image_open_mean_show('00625',newsize,'gray')
dist_00650=image_open_mean_show('00650',newsize,'gray')
dist_00675=image_open_mean_show('00675',newsize,'gray')
dist_00700=image_open_mean_show('00700',newsize,'gray')
dist_00725=image_open_mean_show('00725',newsize,'gray')
dist_00750=image_open_mean_show('00750',newsize,'gray')
dist_00775=image_open_mean_show('00775',newsize,'gray')
dist_00800=image_open_mean_show('00800',newsize,'gray')
dist_00825=image_open_mean_show('00825',newsize,'gray')
dist_00850=image_open_mean_show('00850',newsize,'gray')
dist_00875=image_open_mean_show('00875',newsize,'gray')
dist_00900=image_open_mean_show('00900',newsize,'gray')
dist_00925=image_open_mean_show('00925',newsize,'gray')
dist_00950=image_open_mean_show('00950',newsize,'gray')
dist_00975=image_open_mean_show('00975',newsize,'gray')
dist_01000=image_open_mean_show('01000',newsize,'gray')
dist_01025=image_open_mean_show('01025',newsize,'gray')
dist_01050=image_open_mean_show('01050',newsize,'gray')
dist_01075=image_open_mean_show('01075',newsize,'gray')
dist_01100=image_open_mean_show('01100',newsize,'gray')
dist_01125=image_open_mean_show('01125',newsize,'gray')
dist_01150=image_open_mean_show('01150',newsize,'gray')
dist_01175=image_open_mean_show('01175',newsize,'gray')
dist_01200=image_open_mean_show('01200',newsize,'gray')
dist_01225=image_open_mean_show('01225',newsize,'gray')
dist_01250=image_open_mean_show('01250',newsize,'gray')
dist_01275=image_open_mean_show('01275',newsize,'gray')
dist_01300=image_open_mean_show('01300',newsize,'gray')
dist_01325=image_open_mean_show('01325',newsize,'gray')
dist_01350=image_open_mean_show('01350',newsize,'gray')
dist_01375=image_open_mean_show('01375',newsize,'gray')
dist_01400=image_open_mean_show('01400',newsize,'gray')
dist_01425=image_open_mean_show('01425',newsize,'gray')
dist_01450=image_open_mean_show('01450',newsize,'gray')
dist_01475=image_open_mean_show('01475',newsize,'gray')
dist_01500=image_open_mean_show('01500',newsize,'gray')

# %%
auto_00000=signal.fftconvolve(dist_00000,np.flip(dist_00000),mode='same')
auto_00025=signal.fftconvolve(dist_00025,np.flip(dist_00025),mode='same')
auto_00050=signal.fftconvolve(dist_00050,np.flip(dist_00050),mode='same')
auto_00075=signal.fftconvolve(dist_00075,np.flip(dist_00075),mode='same')
auto_00100=signal.fftconvolve(dist_00100,np.flip(dist_00100),mode='same')
auto_00125=signal.fftconvolve(dist_00125,np.flip(dist_00125),mode='same')
auto_00150=signal.fftconvolve(dist_00150,np.flip(dist_00150),mode='same')
auto_00175=signal.fftconvolve(dist_00175,np.flip(dist_00175),mode='same')
auto_00200=signal.fftconvolve(dist_00200,np.flip(dist_00200),mode='same')
auto_00225=signal.fftconvolve(dist_00225,np.flip(dist_00225),mode='same')
auto_00250=signal.fftconvolve(dist_00250,np.flip(dist_00250),mode='same')
auto_00275=signal.fftconvolve(dist_00275,np.flip(dist_00275),mode='same')
auto_00300=signal.fftconvolve(dist_00300,np.flip(dist_00300),mode='same')
auto_00325=signal.fftconvolve(dist_00325,np.flip(dist_00325),mode='same')
auto_00350=signal.fftconvolve(dist_00350,np.flip(dist_00350),mode='same')
auto_00375=signal.fftconvolve(dist_00375,np.flip(dist_00375),mode='same')
auto_00400=signal.fftconvolve(dist_00400,np.flip(dist_00400),mode='same')
auto_00425=signal.fftconvolve(dist_00425,np.flip(dist_00425),mode='same')
auto_00450=signal.fftconvolve(dist_00450,np.flip(dist_00450),mode='same')
auto_00475=signal.fftconvolve(dist_00475,np.flip(dist_00475),mode='same')
auto_00500=signal.fftconvolve(dist_00500,np.flip(dist_00500),mode='same')
auto_00525=signal.fftconvolve(dist_00525,np.flip(dist_00525),mode='same')
auto_00550=signal.fftconvolve(dist_00550,np.flip(dist_00550),mode='same')
auto_00575=signal.fftconvolve(dist_00575,np.flip(dist_00575),mode='same')
auto_00600=signal.fftconvolve(dist_00600,np.flip(dist_00600),mode='same')
auto_00625=signal.fftconvolve(dist_00625,np.flip(dist_00625),mode='same')
auto_00650=signal.fftconvolve(dist_00650,np.flip(dist_00650),mode='same')
auto_00675=signal.fftconvolve(dist_00675,np.flip(dist_00675),mode='same')
auto_00700=signal.fftconvolve(dist_00700,np.flip(dist_00700),mode='same')
auto_00725=signal.fftconvolve(dist_00725,np.flip(dist_00725),mode='same')
auto_00750=signal.fftconvolve(dist_00750,np.flip(dist_00750),mode='same')
auto_00775=signal.fftconvolve(dist_00775,np.flip(dist_00775),mode='same')
auto_00800=signal.fftconvolve(dist_00800,np.flip(dist_00800),mode='same')
auto_00825=signal.fftconvolve(dist_00825,np.flip(dist_00825),mode='same')
auto_00850=signal.fftconvolve(dist_00850,np.flip(dist_00850),mode='same')
auto_00875=signal.fftconvolve(dist_00875,np.flip(dist_00875),mode='same')
auto_00900=signal.fftconvolve(dist_00900,np.flip(dist_00900),mode='same')
auto_00925=signal.fftconvolve(dist_00925,np.flip(dist_00925),mode='same')
auto_00950=signal.fftconvolve(dist_00950,np.flip(dist_00950),mode='same')
auto_00975=signal.fftconvolve(dist_00975,np.flip(dist_00975),mode='same')
auto_01000=signal.fftconvolve(dist_01000,np.flip(dist_01000),mode='same')
auto_01025=signal.fftconvolve(dist_01025,np.flip(dist_01025),mode='same')
auto_01050=signal.fftconvolve(dist_01050,np.flip(dist_01050),mode='same')
auto_01075=signal.fftconvolve(dist_01075,np.flip(dist_01075),mode='same')
auto_01100=signal.fftconvolve(dist_01100,np.flip(dist_01100),mode='same')
auto_01125=signal.fftconvolve(dist_01125,np.flip(dist_01125),mode='same')
auto_01150=signal.fftconvolve(dist_01150,np.flip(dist_01150),mode='same')
auto_01175=signal.fftconvolve(dist_01175,np.flip(dist_01175),mode='same')
auto_01200=signal.fftconvolve(dist_01200,np.flip(dist_01200),mode='same')
auto_01225=signal.fftconvolve(dist_01225,np.flip(dist_01225),mode='same')
auto_01250=signal.fftconvolve(dist_01250,np.flip(dist_01250),mode='same')
auto_01275=signal.fftconvolve(dist_01275,np.flip(dist_01275),mode='same')
auto_01300=signal.fftconvolve(dist_01300,np.flip(dist_01300),mode='same')
auto_01325=signal.fftconvolve(dist_01325,np.flip(dist_01325),mode='same')
auto_01350=signal.fftconvolve(dist_01350,np.flip(dist_01350),mode='same')
auto_01375=signal.fftconvolve(dist_01375,np.flip(dist_01375),mode='same')
auto_01400=signal.fftconvolve(dist_01400,np.flip(dist_01400),mode='same')
auto_01425=signal.fftconvolve(dist_01425,np.flip(dist_01425),mode='same')
auto_01450=signal.fftconvolve(dist_01450,np.flip(dist_01450),mode='same')
auto_01475=signal.fftconvolve(dist_01475,np.flip(dist_01475),mode='same')
auto_01500=signal.fftconvolve(dist_01500,np.flip(dist_01500),mode='same')

# %%
plt.imshow(auto_00000)
plt.title('00000')
plt.show()

plt.imshow(auto_00100)
plt.title('00100')
plt.show()

plt.imshow(auto_00200)
plt.title('00200')
plt.show()

plt.imshow(auto_00800)
plt.title('00800')
plt.show()

# %%
def fun_ratio(autocon,radi):
    [sy,sx]=autocon.shape
    max_=np.amax(autocon)
    [max_y,max_x]=np.where(autocon==max_)
    max_y=float(max_y)
    max_x=float(max_x)
    disk_mask = np.ones((sy, sx), dtype=float)
    rr, cc = draw.disk((max_y,max_x),radi)
    disk_mask[rr, cc] = 0
    autocon_masked=disk_mask*autocon
    sum_nz=sum(sum(autocon_masked))
    number_nz=autocon.size-len(rr)
    average_nz=sum_nz/number_nz
    ratio_nz=max_/average_nz
    return ratio_nz

radii=2

rati_00000=fun_ratio(auto_00000,radii)
rati_00025=fun_ratio(auto_00025,radii)
rati_00050=fun_ratio(auto_00050,radii)
rati_00075=fun_ratio(auto_00075,radii)
rati_00100=fun_ratio(auto_00100,radii)
rati_00125=fun_ratio(auto_00125,radii)
rati_00150=fun_ratio(auto_00150,radii)
rati_00175=fun_ratio(auto_00175,radii)
rati_00200=fun_ratio(auto_00200,radii)
rati_00225=fun_ratio(auto_00225,radii)
rati_00250=fun_ratio(auto_00250,radii)
rati_00275=fun_ratio(auto_00275,radii)
rati_00300=fun_ratio(auto_00300,radii)
rati_00325=fun_ratio(auto_00325,radii)
rati_00350=fun_ratio(auto_00350,radii)
rati_00375=fun_ratio(auto_00375,radii)
rati_00400=fun_ratio(auto_00400,radii)
rati_00425=fun_ratio(auto_00425,radii)
rati_00450=fun_ratio(auto_00450,radii)
rati_00475=fun_ratio(auto_00475,radii)
rati_00500=fun_ratio(auto_00500,radii)
rati_00525=fun_ratio(auto_00525,radii)
rati_00550=fun_ratio(auto_00550,radii)
rati_00575=fun_ratio(auto_00575,radii)
rati_00600=fun_ratio(auto_00600,radii)
rati_00625=fun_ratio(auto_00625,radii)
rati_00650=fun_ratio(auto_00650,radii)
rati_00675=fun_ratio(auto_00675,radii)
rati_00700=fun_ratio(auto_00700,radii)
rati_00725=fun_ratio(auto_00725,radii)
rati_00750=fun_ratio(auto_00750,radii)
rati_00775=fun_ratio(auto_00775,radii)
rati_00800=fun_ratio(auto_00800,radii)
rati_00825=fun_ratio(auto_00825,radii)
rati_00850=fun_ratio(auto_00850,radii)
rati_00875=fun_ratio(auto_00875,radii)
rati_00900=fun_ratio(auto_00900,radii)
rati_00925=fun_ratio(auto_00925,radii)
rati_00950=fun_ratio(auto_00950,radii)
rati_00975=fun_ratio(auto_00975,radii)
rati_01000=fun_ratio(auto_01000,radii)
rati_01025=fun_ratio(auto_01025,radii)
rati_01050=fun_ratio(auto_01050,radii)
rati_01075=fun_ratio(auto_01075,radii)
rati_01100=fun_ratio(auto_01100,radii)
rati_01125=fun_ratio(auto_01125,radii)
rati_01150=fun_ratio(auto_01150,radii)
rati_01175=fun_ratio(auto_01175,radii)
rati_01200=fun_ratio(auto_01200,radii)
rati_01225=fun_ratio(auto_01225,radii)
rati_01250=fun_ratio(auto_01250,radii)
rati_01275=fun_ratio(auto_01275,radii)
rati_01300=fun_ratio(auto_01300,radii)
rati_01325=fun_ratio(auto_01325,radii)
rati_01350=fun_ratio(auto_01350,radii)
rati_01375=fun_ratio(auto_01375,radii)
rati_01400=fun_ratio(auto_01400,radii)
rati_01425=fun_ratio(auto_01425,radii)
rati_01450=fun_ratio(auto_01450,radii)
rati_01475=fun_ratio(auto_01475,radii)
rati_01500=fun_ratio(auto_01500,radii)

# %%
dist_array=np.array(range(0,1501,25))
rati_array=np.array([rati_00000,rati_00025,rati_00050,rati_00075,rati_00100,rati_00125,rati_00150,rati_00175,rati_00200,rati_00225,rati_00250,rati_00275,rati_00300,rati_00325,rati_00350,rati_00375,rati_00400,rati_00425,rati_00450,rati_00475,rati_00500,rati_00525,rati_00550,rati_00575,rati_00600,rati_00625,rati_00650,rati_00675,rati_00700,rati_00725,rati_00750,rati_00775,rati_00800,rati_00825,rati_00850,rati_00875,rati_00900,rati_00925,rati_00950,rati_00975,rati_01000,rati_01025,rati_01050,rati_01075,rati_01100,rati_01125,rati_01150,rati_01175,rati_01200,rati_01225,rati_01250,rati_01275,rati_01300,rati_01325,rati_01350,rati_01375,rati_01400,rati_01425,rati_01450,rati_01475,rati_01500])
plt.plot(dist_array,rati_array)
plt.show()

# %% [markdown]
# ## Part 2 - Plotting at d=0.0

# %%
plt.imshow(auto_00000)
plt.title('00000')
plt.show()

max00=np.amax(auto_00000)
[max00_y,max00_x]=np.where(auto_00000==max00)
max00_y=int(max00_y)
max00_x=int(max00_x)

plt.plot(auto_00000[:,max00_x])
plt.show()

plt.plot(auto_00000[max00_y:,max00_x])
plt.plot(auto_00000[max00_y:,max00_x]*0)
plt.show()

postive_auto_0000=auto_00000[max00_y:,max00_x]
# thr=1
# for i in range(len(postive_auto_0000)):
#     if postive_auto_0000[i]<=thr:
#         postive_auto_0000[i]=thr

plt.plot(np.log(postive_auto_0000))
plt.show()
# Out:
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_2876\1043116512.py:23: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(postive_auto_0000))

# %%
print(auto_00000[10,max00_x])
# Out:
# 3952.3276027378038

# %%
plt.imshow(np.log(auto_00000))
plt.title('log 00000')
plt.show()
plt.imshow(np.log(auto_00100))
plt.title('log 00100')
plt.show()
plt.imshow(np.log(auto_00200))
plt.title('log 00200')
plt.show()
plt.imshow(np.log(auto_00800))
plt.title('log 00800')
plt.show()
# Out:
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_2876\3667363949.py:1: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(auto_00000))
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_2876\3667363949.py:4: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(auto_00100))
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_2876\3667363949.py:7: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(auto_00200))
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_2876\3667363949.py:10: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(auto_00800))

# %% [markdown]
# ## Part III - The same as *Part I* but limiting the lowest value to 1.

# %%
#Import image
dist_00000 = Image.open('from_camera/test03/dist_00000.png')
realsize=dist_00000.size
factor=4
newsize=tuple(int(ti/factor) for ti in realsize)

def image_open_mean_show(name,new_size,colormap):
    location='from_camera/test03/dist_'+name+'.png'
    image_im = Image.open(location)
    image_im=image_im.resize(new_size,Image.ANTIALIAS)
    image_im = np.array(image_im,dtype=float)
    image_im = image_im[:, :, 0]
    image_im = image_im - image_im.mean()
    plt.imshow(image_im,cmap=colormap)
    plt.title(str(name))
    # plt.show()
    return image_im

dist_00000=image_open_mean_show('00000',newsize,'gray')
dist_00025=image_open_mean_show('00025',newsize,'gray')
dist_00050=image_open_mean_show('00050',newsize,'gray')
dist_00075=image_open_mean_show('00075',newsize,'gray')
dist_00100=image_open_mean_show('00100',newsize,'gray')
dist_00125=image_open_mean_show('00125',newsize,'gray')
dist_00150=image_open_mean_show('00150',newsize,'gray')
dist_00175=image_open_mean_show('00175',newsize,'gray')
dist_00200=image_open_mean_show('00200',newsize,'gray')
dist_00225=image_open_mean_show('00225',newsize,'gray')
dist_00250=image_open_mean_show('00250',newsize,'gray')
dist_00275=image_open_mean_show('00275',newsize,'gray')
dist_00300=image_open_mean_show('00300',newsize,'gray')
dist_00325=image_open_mean_show('00325',newsize,'gray')
dist_00350=image_open_mean_show('00350',newsize,'gray')
dist_00375=image_open_mean_show('00375',newsize,'gray')
dist_00400=image_open_mean_show('00400',newsize,'gray')
dist_00425=image_open_mean_show('00425',newsize,'gray')
dist_00450=image_open_mean_show('00450',newsize,'gray')
dist_00475=image_open_mean_show('00475',newsize,'gray')
dist_00500=image_open_mean_show('00500',newsize,'gray')
dist_00525=image_open_mean_show('00525',newsize,'gray')
dist_00550=image_open_mean_show('00550',newsize,'gray')
dist_00575=image_open_mean_show('00575',newsize,'gray')
dist_00600=image_open_mean_show('00600',newsize,'gray')
dist_00625=image_open_mean_show('00625',newsize,'gray')
dist_00650=image_open_mean_show('00650',newsize,'gray')
dist_00675=image_open_mean_show('00675',newsize,'gray')
dist_00700=image_open_mean_show('00700',newsize,'gray')
dist_00725=image_open_mean_show('00725',newsize,'gray')
dist_00750=image_open_mean_show('00750',newsize,'gray')
dist_00775=image_open_mean_show('00775',newsize,'gray')
dist_00800=image_open_mean_show('00800',newsize,'gray')
dist_00825=image_open_mean_show('00825',newsize,'gray')
dist_00850=image_open_mean_show('00850',newsize,'gray')
dist_00875=image_open_mean_show('00875',newsize,'gray')
dist_00900=image_open_mean_show('00900',newsize,'gray')
dist_00925=image_open_mean_show('00925',newsize,'gray')
dist_00950=image_open_mean_show('00950',newsize,'gray')
dist_00975=image_open_mean_show('00975',newsize,'gray')
dist_01000=image_open_mean_show('01000',newsize,'gray')
dist_01025=image_open_mean_show('01025',newsize,'gray')
dist_01050=image_open_mean_show('01050',newsize,'gray')
dist_01075=image_open_mean_show('01075',newsize,'gray')
dist_01100=image_open_mean_show('01100',newsize,'gray')
dist_01125=image_open_mean_show('01125',newsize,'gray')
dist_01150=image_open_mean_show('01150',newsize,'gray')
dist_01175=image_open_mean_show('01175',newsize,'gray')
dist_01200=image_open_mean_show('01200',newsize,'gray')
dist_01225=image_open_mean_show('01225',newsize,'gray')
dist_01250=image_open_mean_show('01250',newsize,'gray')
dist_01275=image_open_mean_show('01275',newsize,'gray')
dist_01300=image_open_mean_show('01300',newsize,'gray')
dist_01325=image_open_mean_show('01325',newsize,'gray')
dist_01350=image_open_mean_show('01350',newsize,'gray')
dist_01375=image_open_mean_show('01375',newsize,'gray')
dist_01400=image_open_mean_show('01400',newsize,'gray')
dist_01425=image_open_mean_show('01425',newsize,'gray')
dist_01450=image_open_mean_show('01450',newsize,'gray')
dist_01475=image_open_mean_show('01475',newsize,'gray')
dist_01500=image_open_mean_show('01500',newsize,'gray')

# %%
auto_00000=signal.fftconvolve(dist_00000,np.flip(dist_00000),mode='same')
auto_00025=signal.fftconvolve(dist_00025,np.flip(dist_00025),mode='same')
auto_00050=signal.fftconvolve(dist_00050,np.flip(dist_00050),mode='same')
auto_00075=signal.fftconvolve(dist_00075,np.flip(dist_00075),mode='same')
auto_00100=signal.fftconvolve(dist_00100,np.flip(dist_00100),mode='same')
auto_00125=signal.fftconvolve(dist_00125,np.flip(dist_00125),mode='same')
auto_00150=signal.fftconvolve(dist_00150,np.flip(dist_00150),mode='same')
auto_00175=signal.fftconvolve(dist_00175,np.flip(dist_00175),mode='same')
auto_00200=signal.fftconvolve(dist_00200,np.flip(dist_00200),mode='same')
auto_00225=signal.fftconvolve(dist_00225,np.flip(dist_00225),mode='same')
auto_00250=signal.fftconvolve(dist_00250,np.flip(dist_00250),mode='same')
auto_00275=signal.fftconvolve(dist_00275,np.flip(dist_00275),mode='same')
auto_00300=signal.fftconvolve(dist_00300,np.flip(dist_00300),mode='same')
auto_00325=signal.fftconvolve(dist_00325,np.flip(dist_00325),mode='same')
auto_00350=signal.fftconvolve(dist_00350,np.flip(dist_00350),mode='same')
auto_00375=signal.fftconvolve(dist_00375,np.flip(dist_00375),mode='same')
auto_00400=signal.fftconvolve(dist_00400,np.flip(dist_00400),mode='same')
auto_00425=signal.fftconvolve(dist_00425,np.flip(dist_00425),mode='same')
auto_00450=signal.fftconvolve(dist_00450,np.flip(dist_00450),mode='same')
auto_00475=signal.fftconvolve(dist_00475,np.flip(dist_00475),mode='same')
auto_00500=signal.fftconvolve(dist_00500,np.flip(dist_00500),mode='same')
auto_00525=signal.fftconvolve(dist_00525,np.flip(dist_00525),mode='same')
auto_00550=signal.fftconvolve(dist_00550,np.flip(dist_00550),mode='same')
auto_00575=signal.fftconvolve(dist_00575,np.flip(dist_00575),mode='same')
auto_00600=signal.fftconvolve(dist_00600,np.flip(dist_00600),mode='same')
auto_00625=signal.fftconvolve(dist_00625,np.flip(dist_00625),mode='same')
auto_00650=signal.fftconvolve(dist_00650,np.flip(dist_00650),mode='same')
auto_00675=signal.fftconvolve(dist_00675,np.flip(dist_00675),mode='same')
auto_00700=signal.fftconvolve(dist_00700,np.flip(dist_00700),mode='same')
auto_00725=signal.fftconvolve(dist_00725,np.flip(dist_00725),mode='same')
auto_00750=signal.fftconvolve(dist_00750,np.flip(dist_00750),mode='same')
auto_00775=signal.fftconvolve(dist_00775,np.flip(dist_00775),mode='same')
auto_00800=signal.fftconvolve(dist_00800,np.flip(dist_00800),mode='same')
auto_00825=signal.fftconvolve(dist_00825,np.flip(dist_00825),mode='same')
auto_00850=signal.fftconvolve(dist_00850,np.flip(dist_00850),mode='same')
auto_00875=signal.fftconvolve(dist_00875,np.flip(dist_00875),mode='same')
auto_00900=signal.fftconvolve(dist_00900,np.flip(dist_00900),mode='same')
auto_00925=signal.fftconvolve(dist_00925,np.flip(dist_00925),mode='same')
auto_00950=signal.fftconvolve(dist_00950,np.flip(dist_00950),mode='same')
auto_00975=signal.fftconvolve(dist_00975,np.flip(dist_00975),mode='same')
auto_01000=signal.fftconvolve(dist_01000,np.flip(dist_01000),mode='same')
auto_01025=signal.fftconvolve(dist_01025,np.flip(dist_01025),mode='same')
auto_01050=signal.fftconvolve(dist_01050,np.flip(dist_01050),mode='same')
auto_01075=signal.fftconvolve(dist_01075,np.flip(dist_01075),mode='same')
auto_01100=signal.fftconvolve(dist_01100,np.flip(dist_01100),mode='same')
auto_01125=signal.fftconvolve(dist_01125,np.flip(dist_01125),mode='same')
auto_01150=signal.fftconvolve(dist_01150,np.flip(dist_01150),mode='same')
auto_01175=signal.fftconvolve(dist_01175,np.flip(dist_01175),mode='same')
auto_01200=signal.fftconvolve(dist_01200,np.flip(dist_01200),mode='same')
auto_01225=signal.fftconvolve(dist_01225,np.flip(dist_01225),mode='same')
auto_01250=signal.fftconvolve(dist_01250,np.flip(dist_01250),mode='same')
auto_01275=signal.fftconvolve(dist_01275,np.flip(dist_01275),mode='same')
auto_01300=signal.fftconvolve(dist_01300,np.flip(dist_01300),mode='same')
auto_01325=signal.fftconvolve(dist_01325,np.flip(dist_01325),mode='same')
auto_01350=signal.fftconvolve(dist_01350,np.flip(dist_01350),mode='same')
auto_01375=signal.fftconvolve(dist_01375,np.flip(dist_01375),mode='same')
auto_01400=signal.fftconvolve(dist_01400,np.flip(dist_01400),mode='same')
auto_01425=signal.fftconvolve(dist_01425,np.flip(dist_01425),mode='same')
auto_01450=signal.fftconvolve(dist_01450,np.flip(dist_01450),mode='same')
auto_01475=signal.fftconvolve(dist_01475,np.flip(dist_01475),mode='same')
auto_01500=signal.fftconvolve(dist_01500,np.flip(dist_01500),mode='same')

# %%
plt.imshow(auto_00000)
plt.title('00000')
plt.show()

plt.imshow(auto_00100)
plt.title('00100')
plt.show()

plt.imshow(auto_00200)
plt.title('00200')
plt.show()

plt.imshow(auto_00800)
plt.title('00800')
plt.show()

# %%
def fun_ratio(autocon,radi):
    [sy,sx]=autocon.shape
    max_=np.amax(autocon)
    [max_y,max_x]=np.where(autocon==max_)
    max_y=float(max_y)
    max_x=float(max_x)
    disk_mask = np.ones((sy, sx), dtype=float)
    rr, cc = draw.disk((max_y,max_x),radi)
    disk_mask[rr, cc] = 0
    autocon = np.maximum(autocon,np.ones(autocon.shape)) ### HERE !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    autocon_masked=disk_mask*autocon
    sum_nz=sum(sum(autocon_masked))
    number_nz=autocon.size-len(rr)
    average_nz=sum_nz/number_nz
    ratio_nz=max_/average_nz
    return ratio_nz

radii=2 ##

rati_00000=fun_ratio(auto_00000,radii)
rati_00025=fun_ratio(auto_00025,radii)
rati_00050=fun_ratio(auto_00050,radii)
rati_00075=fun_ratio(auto_00075,radii)
rati_00100=fun_ratio(auto_00100,radii)
rati_00125=fun_ratio(auto_00125,radii)
rati_00150=fun_ratio(auto_00150,radii)
rati_00175=fun_ratio(auto_00175,radii)
rati_00200=fun_ratio(auto_00200,radii)
rati_00225=fun_ratio(auto_00225,radii)
rati_00250=fun_ratio(auto_00250,radii)
rati_00275=fun_ratio(auto_00275,radii)
rati_00300=fun_ratio(auto_00300,radii)
rati_00325=fun_ratio(auto_00325,radii)
rati_00350=fun_ratio(auto_00350,radii)
rati_00375=fun_ratio(auto_00375,radii)
rati_00400=fun_ratio(auto_00400,radii)
rati_00425=fun_ratio(auto_00425,radii)
rati_00450=fun_ratio(auto_00450,radii)
rati_00475=fun_ratio(auto_00475,radii)
rati_00500=fun_ratio(auto_00500,radii)
rati_00525=fun_ratio(auto_00525,radii)
rati_00550=fun_ratio(auto_00550,radii)
rati_00575=fun_ratio(auto_00575,radii)
rati_00600=fun_ratio(auto_00600,radii)
rati_00625=fun_ratio(auto_00625,radii)
rati_00650=fun_ratio(auto_00650,radii)
rati_00675=fun_ratio(auto_00675,radii)
rati_00700=fun_ratio(auto_00700,radii)
rati_00725=fun_ratio(auto_00725,radii)
rati_00750=fun_ratio(auto_00750,radii)
rati_00775=fun_ratio(auto_00775,radii)
rati_00800=fun_ratio(auto_00800,radii)
rati_00825=fun_ratio(auto_00825,radii)
rati_00850=fun_ratio(auto_00850,radii)
rati_00875=fun_ratio(auto_00875,radii)
rati_00900=fun_ratio(auto_00900,radii)
rati_00925=fun_ratio(auto_00925,radii)
rati_00950=fun_ratio(auto_00950,radii)
rati_00975=fun_ratio(auto_00975,radii)
rati_01000=fun_ratio(auto_01000,radii)
rati_01025=fun_ratio(auto_01025,radii)
rati_01050=fun_ratio(auto_01050,radii)
rati_01075=fun_ratio(auto_01075,radii)
rati_01100=fun_ratio(auto_01100,radii)
rati_01125=fun_ratio(auto_01125,radii)
rati_01150=fun_ratio(auto_01150,radii)
rati_01175=fun_ratio(auto_01175,radii)
rati_01200=fun_ratio(auto_01200,radii)
rati_01225=fun_ratio(auto_01225,radii)
rati_01250=fun_ratio(auto_01250,radii)
rati_01275=fun_ratio(auto_01275,radii)
rati_01300=fun_ratio(auto_01300,radii)
rati_01325=fun_ratio(auto_01325,radii)
rati_01350=fun_ratio(auto_01350,radii)
rati_01375=fun_ratio(auto_01375,radii)
rati_01400=fun_ratio(auto_01400,radii)
rati_01425=fun_ratio(auto_01425,radii)
rati_01450=fun_ratio(auto_01450,radii)
rati_01475=fun_ratio(auto_01475,radii)
rati_01500=fun_ratio(auto_01500,radii)

dist_array=np.array(range(0,1501,25))
rati_array=np.array([rati_00000,rati_00025,rati_00050,rati_00075,rati_00100,rati_00125,rati_00150,rati_00175,rati_00200,rati_00225,rati_00250,rati_00275,rati_00300,rati_00325,rati_00350,rati_00375,rati_00400,rati_00425,rati_00450,rati_00475,rati_00500,rati_00525,rati_00550,rati_00575,rati_00600,rati_00625,rati_00650,rati_00675,rati_00700,rati_00725,rati_00750,rati_00775,rati_00800,rati_00825,rati_00850,rati_00875,rati_00900,rati_00925,rati_00950,rati_00975,rati_01000,rati_01025,rati_01050,rati_01075,rati_01100,rati_01125,rati_01150,rati_01175,rati_01200,rati_01225,rati_01250,rati_01275,rati_01300,rati_01325,rati_01350,rati_01375,rati_01400,rati_01425,rati_01450,rati_01475,rati_01500])
plt.plot(dist_array,rati_array)
plt.title('autocon=max(autocon,1)')
plt.show()

# %%
plt.imshow(np.log(np.maximum(auto_00000,np.ones(auto_00100.shape))))
plt.title('log 00000')
plt.show()
plt.imshow(np.log(np.maximum(auto_00100,np.ones(auto_00100.shape))))
plt.title('log 00100')
plt.show()
plt.imshow(np.log(np.maximum(auto_00200,np.ones(auto_00100.shape))))
plt.title('log 00200')
plt.show()
plt.imshow(np.log(np.maximum(auto_00800,np.ones(auto_00100.shape))))
plt.title('log 00800')
plt.show()

# %% [markdown]
# # Iterative Hard Thresholding

# %% [markdown]
# Experiment with test16

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import math
from skimage import draw
from scipy import signal
from PIL import Image
import pywt
import pywt.data
from utils_wavelet import *
import scipy.stats as stats

# %%
def fun_conv(A,B):
    conv = signal.fftconvolve(A,B,mode='same')
    return conv

def naive_conv(A,B):
    C = np.zeros(len(A))
    for i in range(len(A)):
        C[i] = np.sum(A*np.roll(np.roll(np.flip(B),1),i))
    return C

def manual_conv(A,B):
    C = np.zeros(len(A))
    for m in range(len(A)):
        for i in range(len(B)):
            C[m] += A[i]*B[m-i]
    return C

def fun_auto(A):
    auto = signal.fftconvolve(A,np.flip(A),mode='same')
    return auto

def imshowArray(arr):
    plt.imshow((arr,arr))
    plt.ylim([0,1])

def npArray2arrayList(a_vector):
    fake_a_coef = pywt.wavedec(a_vector,'db1')
    a_vector_array = vec2arrayList(a_vector,fake_a_coef)
    return a_vector_array

def npMatrix2arrayList(a_matrix):
    fake_a_coef = pywt.wavedec2(a_matrix,'db1')
    a_vector_array = vec2arrayList(a_matrix.flatten(),fake_a_coef)
    return a_vector_array

def L0norm(vector,zero=1e-5):
    return vector[np.where(abs(vector)>zero)].size

global_factor = 4

def image_open(location):
    image_im = Image.open(location)
    realsize=image_im.size
    newsize=tuple(int(ti/global_factor) for ti in realsize)
    image_im=image_im.resize(newsize,Image.ANTIALIAS)
    image_im = np.array(image_im,dtype=float)
    image_im = image_im[:,:,0]
    return image_im

def image_open_newsize(location,newsize):
    image_im = Image.open(location)
    image_im=image_im.resize(newsize,Image.ANTIALIAS)
    image_im = np.array(image_im,dtype=float)
    image_im = image_im[:,:,0]
    return image_im

def psi_op(alpha):
    return pywt.waverec2(npMatrix2arrayList(alpha),'db1')

def psi_adj_op(x_signal):
    return arrayList2vec(pywt.wavedec2(x_signal,'db1'))

def flipNroll(matrix):
    # return np.roll(np.flip(matrix),(1, 1), axis=(1, 0))
    return np.roll(np.flip(matrix),(-1, -1), axis=(0, 1))
    # return np.flip(np.roll(matrix,(-1, -1), axis=(0, 1)))

def inf_norm(matrix):
    return max(abs(row.sum()) for row in matrix)

wtype = 'db1'

def waverec2fromArray(my_array):
    wdec = pywt.wavedec2(my_array,wavelet=wtype)
    wcoef, wslices = pywt.coeffs_to_array(wdec)
    my_coef = pywt.array_to_coeffs(my_array,wslices,'wavedec2')
    output = pywt.waverec2(my_coef,wtype)
    return output

def wavedec2toArray(my_array):
    output  = pywt.coeffs_to_array(pywt.wavedec2(my_array,wavelet=wtype))[0]
    return output

# %% [markdown]
# Size of the matrices

# %%
sx = 128
sy = 256

# %% [markdown]
# PSF H and Image Y

# %%
h = np.zeros((sx,sy))
h_black = np.zeros((sx,sy))
image = np.zeros((sx,sy))
backlight = np.zeros((sx,sy))
for i in range(1):
    h = image_open_newsize('from_camera/test10/h.png',(sy,sx))
    h_black = image_open_newsize('from_camera/test10/h_black.png',(sy,sx))

h /= 20
h_black /= 20   

h = np.flip(h-h_black)
h -= np.mean(h)

# h = np.zeros((sx,sy))
# h[math.floor(sx/2)-1,math.floor(sy/2)-1] = 1

h /= np.linalg.norm(h)/0.99

x_GT = np.zeros((h.shape))

plt.figure(figsize=(20,5))
plt.subplot(1,4,1)
plt.imshow(h,cmap='gray')
plt.colorbar(orientation='horizontal')
plt.title('h')
plt.subplot(1,4,2)
plt.imshow(h_black,cmap='gray')
plt.colorbar(orientation='horizontal')
plt.title('h_black')
# plt.subplot(1,4,3)
# plt.imshow(y,cmap='gray')
# plt.colorbar(orientation='horizontal')
# plt.title('y')
plt.subplot(1,4,4)
plt.imshow(backlight,cmap='gray')
plt.colorbar(orientation='horizontal')
plt.title('backlight')
plt.show()

# %%
x_GT = image_open_newsize('images/face2.png',(sy,sx))/255
y = fun_conv(x_GT,h)
y -= np.mean(y)
y /= np.linalg.norm(y)/0.99

print(x_GT[np.where(x_GT>(1e-5))].size) #L0 norm

plt.figure(figsize=(10,10))
plt.imshow(x_GT,cmap='gray')
plt.colorbar(orientation='horizontal')
plt.show()
# Out:
# 4658

# %% [markdown]
# IHT

# %%
#stepsize
# Ninf = inf_norm(np.fft.fft2(h))
# mu = 0.5/(Ninf**2)
mu = 0.0001
print(mu)

#stop condition
NS = sx*sy
est_mu = np.sum(y)/NS
est_sig = np.sum((y-est_mu)**2)/(NS-1)
noise1 = (NS*2*np.var(y))**0.5
noise2 = (2*np.var(y)*(NS+2*((NS)**0.5)))**0.5

print(noise1, noise2)
print(est_mu)
print(est_sig)
print(np.var(y))
# Out:
# 0.0001
# 1.4000714267493641 1.40778455556329
# 4.336808689942018e-19
# 2.991119113742485e-05
# 2.9910278320312503e-05

# %%
alfa_k = np.zeros(x_GT.shape)
k = 0
s = 500
# mu = 1e-6
big = 100
plotting_threshold = np.array([])
plotting_stop = np.array([])

while (k<s):
    #upgrade 'big'
    plotting_threshold = np.append(plotting_threshold,big)
    if (big < 1000):
        big += 10
    
    #gradient descent
    gradient = wavedec2toArray(fun_conv(flipNroll(h),(y-fun_conv(h,waverec2fromArray(alfa_k)))))
    beta = alfa_k + mu*gradient

    #hard thresholding
    beta = beta.flatten()
    big_element = np.sort(abs(beta))[-big]   #The ht biggest elements
    beta[abs(beta)<big_element] = 0          #if (coef < ht_biggest_element): coef = 0            
    alfa_k = beta.reshape(x_GT.shape)

    #stop?
    stop_k = np.linalg.norm(y-fun_conv(h,waverec2fromArray(alfa_k)))
    plotting_stop = np.append(plotting_stop,stop_k)
    
    #next
    k += 1
    print('k ←',k)

a_IHTA = np.copy(alfa_k)
x_IHTA = waverec2fromArray(a_IHTA)

plt.figure(figsize=(10,8))
plt.imshow(x_IHTA,cmap='gray')
plt.title('x (recovered via IHTA)')
plt.colorbar(orientation="horizontal")
plt.show()
# Out:
# k ← 1
# k ← 2
# k ← 3
# k ← 4
# k ← 5
# k ← 6
# k ← 7
# k ← 8
# k ← 9
# k ← 10
# k ← 11
# k ← 12
# k ← 13
# k ← 14
# k ← 15
# k ← 16
# k ← 17
# k ← 18
# k ← 19
# k ← 20
# k ← 21
# k ← 22
# k ← 23
# k ← 24
# k ← 25
# k ← 26
# k ← 27
# k ← 28
# k ← 29
# k ← 30
# k ← 31
# k ← 32
# k ← 33
# k ← 34
# k ← 35
# k ← 36
# k ← 37
# k ← 38
# k ← 39
# k ← 40
# k ← 41
# k ← 42
# k ← 43
# k ← 44
# k ← 45
# k ← 46
# k ← 47
# k ← 48
# k ← 49
# k ← 50
# k ← 51
# k ← 52
# k ← 53
# k ← 54
# k ← 55
# k ← 56
# k ← 57
# k ← 58
# k ← 59
# k ← 60
# k ← 61
# k ← 62
# k ← 63
# k ← 64
# k ← 65
# k ← 66
# k ← 67
# k ← 68
# k ← 69
# k ← 70
# k ← 71
# k ← 72
# k ← 73
# k ← 74
# k ← 75
# k ← 76
# k ← 77
# k ← 78
# k ← 79
# k ← 80
# k ← 81
# k ← 82
# k ← 83
# k ← 84
# k ← 85
# k ← 86
# k ← 87
# k ← 88
# k ← 89
# k ← 90
# k ← 91
# k ← 92
# k ← 93
# k ← 94
# k ← 95
# k ← 96
# k ← 97
# k ← 98
# k ← 99
# k ← 100
# k ← 101
# k ← 102
# k ← 103
# k ← 104
# k ← 105
# k ← 106
# k ← 107
# k ← 108
# k ← 109
# k ← 110
# k ← 111
# k ← 112
# k ← 113
# k ← 114
# k ← 115
# k ← 116
# k ← 117
# k ← 118
# k ← 119
# k ← 120
# k ← 121
# k ← 122
# k ← 123
# k ← 124
# k ← 125
# k ← 126
# k ← 127
# k ← 128
# k ← 129
# k ← 130
# k ← 131
# k ← 132
# k ← 133
# k ← 134
# k ← 135
# k ← 136
# k ← 137
# k ← 138
# k ← 139
# k ← 140
# k ← 141
# k ← 142
# k ← 143
# k ← 144
# k ← 145
# k ← 146
# k ← 147
# k ← 148
# k ← 149
# k ← 150
# k ← 151
# k ← 152
# k ← 153
# k ← 154
# k ← 155
# k ← 156
# k ← 157
# k ← 158
# k ← 159
# k ← 160
# k ← 161
# k ← 162
# k ← 163
# k ← 164
# k ← 165
# k ← 166
# k ← 167
# k ← 168
# k ← 169
# k ← 170
# k ← 171
# k ← 172
# k ← 173
# k ← 174
# k ← 175
# k ← 176
# k ← 177
# k ← 178
# k ← 179
# k ← 180
# k ← 181
# k ← 182
# k ← 183
# k ← 184
# k ← 185
# k ← 186
# k ← 187
# k ← 188
# k ← 189
# k ← 190
# k ← 191
# k ← 192
# k ← 193
# k ← 194
# k ← 195
# k ← 196
# k ← 197
# k ← 198
# k ← 199
# k ← 200
# k ← 201
# k ← 202
# k ← 203
# k ← 204
# k ← 205
# k ← 206
# k ← 207
# k ← 208
# k ← 209
# k ← 210
# k ← 211
# k ← 212
# k ← 213
# k ← 214
# k ← 215
# k ← 216
# k ← 217
# k ← 218
# k ← 219
# k ← 220
# k ← 221
# k ← 222
# k ← 223
# k ← 224
# k ← 225
# k ← 226
# k ← 227
# k ← 228
# k ← 229
# k ← 230
# k ← 231
# k ← 232
# k ← 233
# k ← 234
# k ← 235
# k ← 236
# k ← 237
# k ← 238
# k ← 239
# k ← 240
# k ← 241
# k ← 242
# k ← 243
# k ← 244
# k ← 245
# k ← 246
# k ← 247
# k ← 248
# k ← 249
# k ← 250
# k ← 251
# k ← 252
# k ← 253
# k ← 254
# k ← 255
# k ← 256
# k ← 257
# k ← 258
# k ← 259
# k ← 260
# k ← 261
# k ← 262
# k ← 263
# k ← 264
# k ← 265
# k ← 266
# k ← 267
# k ← 268
# k ← 269
# k ← 270
# k ← 271
# k ← 272
# k ← 273
# k ← 274
# k ← 275
# k ← 276
# k ← 277
# k ← 278
# k ← 279
# k ← 280
# k ← 281
# k ← 282
# k ← 283
# k ← 284
# k ← 285
# k ← 286
# k ← 287
# k ← 288
# k ← 289
# k ← 290
# k ← 291
# k ← 292
# k ← 293
# k ← 294
# k ← 295
# k ← 296
# k ← 297
# k ← 298
# k ← 299
# k ← 300
# k ← 301
# k ← 302
# k ← 303
# k ← 304
# k ← 305
# k ← 306
# k ← 307
# k ← 308
# k ← 309
# k ← 310
# k ← 311
# k ← 312
# k ← 313
# k ← 314
# k ← 315
# k ← 316
# k ← 317
# k ← 318
# k ← 319
# k ← 320
# k ← 321
# k ← 322
# k ← 323
# k ← 324
# k ← 325
# k ← 326
# k ← 327
# k ← 328
# k ← 329
# k ← 330
# k ← 331
# k ← 332
# k ← 333
# k ← 334
# k ← 335
# k ← 336
# k ← 337
# k ← 338
# k ← 339
# k ← 340
# k ← 341
# k ← 342
# k ← 343
# k ← 344
# k ← 345
# k ← 346
# k ← 347
# k ← 348
# k ← 349
# k ← 350
# k ← 351
# k ← 352
# k ← 353
# k ← 354
# k ← 355
# k ← 356
# k ← 357
# k ← 358
# k ← 359
# k ← 360
# k ← 361
# k ← 362
# k ← 363
# k ← 364
# k ← 365
# k ← 366
# k ← 367
# k ← 368
# k ← 369
# k ← 370
# k ← 371
# k ← 372
# k ← 373
# k ← 374
# k ← 375
# k ← 376
# k ← 377
# k ← 378
# k ← 379
# k ← 380
# k ← 381
# k ← 382
# k ← 383
# k ← 384
# k ← 385
# k ← 386
# k ← 387
# k ← 388
# k ← 389
# k ← 390
# k ← 391
# k ← 392
# k ← 393
# k ← 394
# k ← 395
# k ← 396
# k ← 397
# k ← 398
# k ← 399
# k ← 400
# k ← 401
# k ← 402
# k ← 403
# k ← 404
# k ← 405
# k ← 406
# k ← 407
# k ← 408
# k ← 409
# k ← 410
# k ← 411
# k ← 412
# k ← 413
# k ← 414
# k ← 415
# k ← 416
# k ← 417
# k ← 418
# k ← 419
# k ← 420
# k ← 421
# k ← 422
# k ← 423
# k ← 424
# k ← 425
# k ← 426
# k ← 427
# k ← 428
# k ← 429
# k ← 430
# k ← 431
# k ← 432
# k ← 433
# k ← 434
# k ← 435
# k ← 436
# k ← 437
# k ← 438
# k ← 439
# k ← 440
# k ← 441
# k ← 442
# k ← 443
# k ← 444
# k ← 445
# k ← 446
# k ← 447
# k ← 448
# k ← 449
# k ← 450
# k ← 451
# k ← 452
# k ← 453
# k ← 454
# k ← 455
# k ← 456
# k ← 457
# k ← 458
# k ← 459
# k ← 460
# k ← 461
# k ← 462
# k ← 463
# k ← 464
# k ← 465
# k ← 466
# k ← 467
# k ← 468
# k ← 469
# k ← 470
# k ← 471
# k ← 472
# k ← 473
# k ← 474
# k ← 475
# k ← 476
# k ← 477
# k ← 478
# k ← 479
# k ← 480
# k ← 481
# k ← 482
# k ← 483
# k ← 484
# k ← 485
# k ← 486
# k ← 487
# k ← 488
# k ← 489
# k ← 490
# k ← 491
# k ← 492
# k ← 493
# k ← 494
# k ← 495
# k ← 496
# k ← 497
# k ← 498
# k ← 499
# k ← 500

# %%
plt.figure(figsize=(20,15))

plt.subplot(3,3,1)
plt.imshow(x_IHTA,cmap='gray')
plt.title('x (recovered via IHTA)')
plt.colorbar(orientation="horizontal")

plt.subplot(3,3,2)
plt.imshow(a_IHTA,cmap='gray')
plt.title('a_IHTA')
plt.colorbar(orientation="horizontal")

plt.subplot(3,3,3)
plt.imshow(y,cmap='gray')
plt.title('y')
plt.colorbar(orientation="horizontal")

plt.subplot(3,3,4)
plt.imshow(h,cmap='gray')
plt.title('h')
plt.colorbar(orientation="horizontal")

plt.subplot(3,3,5)
plt.plot(plotting_threshold)
plt.title('threshold')

plt.subplot(3,3,6)
plt.plot(plotting_stop)
plt.title('stop')

# plt.savefig('resultats/ihta_2d1.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# FLIP

# %%
plt.figure(figsize=(10,8))
# plt.plot(weight_array)
plt.imshow((x_IHTA),cmap = 'gray')
plt.colorbar(orientation='horizontal')
plt.savefig('resultats/final2/fx6.png', bbox_inches='tight')

# %%
plt.figure(figsize=(10,8))
plt.plot(plotting_stop)
plt.savefig('resultats/final2/fs6.png', bbox_inches='tight')

# %%
valor = 20*np.log10(np.linalg.norm(x_GT)/np.linalg.norm(x_GT-x_IHTA))
print(valor)

plt.imshow(x_GT-x_IHTA)
# Out:
# 0.010966744142653563
